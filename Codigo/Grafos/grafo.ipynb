# %%
from pyvis.network import Network
import networkx as nx

# Create the graph
G = nx.Graph()

# Add nodes for people and projects
people = ["Adrián C","Alexis P","Antonieta K","Andrés VB",
          "Belén A",
          "Carlos J","Carolina P","Camila PS",
          "Darian Y","Denise M","Dayana M",
          "Ezequiel O",
          "Fernando R","Fernando P","Federico G","Florencia R","Federico V",
          "Gimena dVI",
          "Hugo IC",
          "Javier L","Javier O","Juan AV","Juan CI","Joaquin B","Joaquin F","Juan G","Josefina V",
          "Lucía P","Loana S","Leandro A","Luis FI","Lucas ER",
          "Mariano L","María RM", "Matías S","Mariano PP",
          "Natalia D","Natalia M","Nicolás P",
          "Paula V","Pablo B",
          "Rodrigo A",
          "Tomás T",
          "Valentín C"         
          ]

projects = ["Asistentes Bancarios",
            "AI Testing Conversacional",
            "Formulario con Audios E2",
            "Comparativo de Asistentes",
            "Implementación Whatsapp",
            "Asistente de Políticas Internas - Copilot",
            "LLM Research",
            "Conversacional Audio Formularios E1",
            "Athena E1",
            "Generador Ideas Comerciales",
            "STONEX",
            "Contratos Legales",
            "YPF - Flujogramas",
            "AI Testing",
            "Open Source LLM",
            "Tramarsa",
            "Calidad Asistente Híbrido",
            "Testeo de Modelos de IA Generativa",
            "Human Feedback",
            "Asistente Empleados de Practia",
            "Asistente Políticas Internas",
            "Detección de Indumentaria",
            "Forecast - Fabric",
            "Forecast Azure ML",
            "Anomalías - Fabric",
            "Anomalías Azure ML",
            "Segmentación Clientes - Fabric",
            "Segmentación Clientes - Azure ML",
            "Minera Centinela",
            "Lubricantes ENEX",
            "RL - Minera Centinela E1",
            "Anomalías Equipos Rotativos",
            "VideoIndexer E1",
            "RL - Minera Centinela E2"]

# Add nodes with types
G.add_nodes_from(people, bipartite=0)
G.add_nodes_from(projects, bipartite=1)

# Connect edges
edges = [
    ("Adrián C","Asistentes Bancarios"),
    ("Adrián C","AI Testing Conversacional"),
    ("Adrián C","Asistente de Políticas Internas - Copilot"),
    ("Adrián C","Asistente Empleados de Practia"),
    ("Adrián C","Asistente Políticas Internas"),
    ("Alexis P","Forecast Azure ML"),
    ("Alexis P","Anomalías Azure ML"),
    ("Antonieta K","AI Testing Conversacional"),
    ("Antonieta K","Asistente de Políticas Internas - Copilot"),
    ("Antonieta K","Conversacional Audio Formularios E1"),
    ("Antonieta K","Athena E1"),
    ("Antonieta K","Human Feedback"),
    ("Andrés VB","Anomalías Equipos Rotativos"),
    ("Belén A","Generador Ideas Comerciales"),
    ("Belén A","STONEX"),
    ("Belén A","Contratos Legales"),
    ("Belén A","YPF - Flujogramas"),
    ("Belén A","AI Testing"),
    ("Belén A","Open Source LLM"),
    ("Belén A","Tramarsa"),
    ("Belén A","Calidad Asistente Híbrido"),
    ("Carlos J","Forecast Azure ML"),
    ("Carlos J","Anomalías Azure ML"),
    ("Carolina P","Asistente de Políticas Internas - Copilot"),
    ("Camila PS","VideoIndexer E1"),
    ("Camila PS","Athena E1"),
    ("Darian Y","Human Feedback"),
    ("Denise M","AI Testing Conversacional"),
    ("Denise M","LLM Research"),
    ("Denise M","Testeo de Modelos de IA Generativa"),
    ("Dayana M","AI Testing Conversacional"),
    ("Dayana M","YPF - Flujogramas"),
    ("Dayana M","Open Source LLM"),
    ("Dayana M","Calidad Asistente Híbrido"),
    ("Ezequiel O","AI Testing Conversacional"),
    ("Ezequiel O","YPF - Flujogramas"),
    ("Ezequiel O","AI Testing"),
    ("Ezequiel O","Open Source LLM"),
    ("Ezequiel O","Calidad Asistente Híbrido"),
    ("Fernando R","VideoIndexer E1"),
    ("Fernando P","Lubricantes ENEX"),
    ("Fernando P","RL - Minera Centinela E1"),
    ("Fernando P","RL - Minera Centinela E2"),
    ("Federico G","RL - Minera Centinela E1"),
    ("Federico G","RL - Minera Centinela E2"),
    ("Federico G","VideoIndexer E1"),
    ("Florencia R","YPF - Flujogramas"),
    ("Florencia R","AI Testing"),
    ("Florencia R","Open Source LLM"),
    ("Florencia R","Tramarsa"),
    ("Federico V","Asistente Empleados de Practia"),
    ("Gimena dVI","VideoIndexer E1"),
    ("Gimena dVI","Minera Centinela"),
    ("Gimena dVI","Detección de Indumentaria"),
    ("Hugo IC","VideoIndexer E1"),
    ("Javier L","Generador Ideas Comerciales"),
    ("Javier L","Stonex"),
    ("Javier L","Tramarsa"),
    ("Javier L","Forecast Azure ML"),
    ("Javier L","Anomalías Azure ML"),
    ("Javier L","Segmentación Clientes - Azure ML"),
    ("Javier L","Minera Centinela"),
    ("Javier L","Anomalías Equipos Rotativos"),
    ("Javier O","Contratos Legales"),
    ("Javier O","Detección de Indumentaria"),
    ("Javier O","Forecast Azure ML"),
    ("Javier O","Anomalías Azure ML"),
    ("Javier O","Segmentación Clientes - Azure ML"),
    ("Juan AV","Testeo de Modelos de IA Generativa"),
    ("Juan CI","AI Testing Conversacional"),
    ("Juan CI","LLM Research"),
    ("Juan CI","Testeo de Modelos de IA Generativa"),
    ("Joaquin B","Asistentes Bancarios"),
    ("Joaquin B","AI Testing Conversacional"),
    ("Joaquin B","Formulario con Audios E2"),
    ("Joaquin B","Comparativo de Asistentes"),
    ("Joaquin B","Implementación Whatsapp"),
    ("Joaquin B","LLM Research"),
    ("Joaquin B","Conversacional Audio Formularios E1"),
    ("Joaquin B","Athena E1"),
    ("Joaquin B","Asistente Empleados de Practia"),
    ("Joaquin B","Asistente Políticas Internas"),
    ("Joaquin F","RL - Minera Centinela E1"),
    ("Joaquin F","RL - Minera Centinela E2"),
    ("Juan G","Asistentes Bancarios"),
    ("Juan G","Asistente de Políticas Internas - Copilot"),
    ("Josefina V","YPF - Flujogramas"),
    ("Josefina V","AI Testing"),
    ("Josefina V","Open Source LLM"),
    ("Lucía P","Asistente de Políticas Internas - Copilot"),
    ("Loana S","AI Testing Conversacional"),
    ("Loana S","LLM Research"),
    ("Loana S","Testeo de Modelos de IA Generativa"),
    ("Leandro A","Formulario con Audios E2"),
    ("Leandro A","Comparativo de Asistentes"),
    ("Leandro A","Implementación Whatsapp"),
    ("Leandro A","Calidad Asistente Híbrido"),
    ("Leandro A","Asistente Políticas Internas"),
    ("Luis FI","Contratos Legales"),
    ("Luis FI","Detección de Indumentaria"),
    ("Luis FI","Forecast Azure ML"),
    ("Luis FI","Anomalías Azure ML"),
    ("Luis FI","Segmentación Clientes - Azure ML"),
    ("Lucas ER","Segmentación Clientes - Fabric"),
    ("Lucas ER","Detección de Indumentaria"),
    ("Lucas ER","Anomalías - Fabric"),
    ("Lucas ER","Forecast - Fabric"),
    ("Mariano L","Athena E1"),
    ("Mariano L","Asistentes Bancarios"),
    ("Mariano L","Asistente de Políticas Internas - Copilot"),
    ("María RM","Minera Centinela"),
    ("Matías S","Athena E1"),
    ("Mariano PP","Human Feedback"),
    ("Natalia D","Open Source LLM"),
    ("Natalia D","Anomalías Equipos Rotativos"),
    ("Natalia M","Segmentación Clientes - Fabric"),
    ("Natalia M","Anomalías - Fabric"),
    ("Natalia M","Forecast - Fabric"),
    ("Nicolás P","Athena E1"),
    ("Nicolás P","Human Feedback"),
    ("Paula V","Anomalías Equipos Rotativos"),
    ("Paula V","RL - Minera Centinela E1"),
    ("Paula V","RL - Minera Centinela E2"),
    ("Paula V","Lubricantes ENEX"),
    ("Paula V","VideoIndexer E1"),
    ("Pablo B","Formulario con Audios E2"),
    ("Pablo B","Comparativo de Asistentes"),
    ("Pablo B","Implementación Whatsapp"),
    ("Pablo B","AI Testing"),
    ("Pablo B","Calidad Asistente Híbrido"),
    ("Rodrigo A","Athena E1"),
    ("Rodrigo A","Implementación Whatsapp"),
    ("Tomás T","AI Testing"),
    ("Valentín C","Conversacional Audio Formularios E1"),
    ("Valentín C","Athena E1"),
    ("Valentín C","Human Feedback")
]
    
G.add_edges_from(edges)

# Create Pyvis network object
net = Network(height="1000px",notebook=True, directed=False,neighborhood_highlight=True)#,bgcolor="#e5dada")

# Add nodes with distinct colors for people vs projects
for node in G.nodes():
    if node in people:
        net.add_node(node, label=node, color='#ff6b6b', title=node, shape="circle", labelHighlightBold=True)  # People nodes are orange
    else:
        net.add_node(node, label=node, color='#4ecdc4', title=node, labelHighlightBold=True)  # Project nodes are blue 

# Add edges
for edge in G.edges():
    net.add_edge(edge[0], edge[1],color='#292f36')


# Save and display the visualization
net.show('interactive_network.html')
# Out:
# ...
# interactive_network.html
#         <iframe
#             width="100%"
#             height="1000px"
#             src="interactive_network.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
